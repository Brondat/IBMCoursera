# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bronson** <br>
# I want to become a Data Analyst!

# %% [markdown]
# *I am interested in data science because data is at the center of any organization! No matter which career I find myself in, I will be able to apply data science skills that will further organizational objectives as well as my own career advancement.*

# %% [markdown]
# ### In Cell 5 the sum of 10 and 10 is calculated which results in 20.

# %%
10+10
# Out:
# 20

# %% [markdown]
# - This bulleted list is one of three items
#     - This is a sub-bullet!
#     - The second item is a table
#     - The third item is an image <br>
# |Name|Excitement|Cell 6 Requirements Met So Far|
# |-------|----|-|
# |Bronson|High|2|
#
# ![image.png](attachment:cd33ee9f-ec4d-4abd-bbbb-7db4737b9c08.png)
